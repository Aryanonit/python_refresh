# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanonit/python_refresh/blob/main/python_refresh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("kya hai")
# Out:
# kya hai

# %%
name = input('kya chahiye ')
print("hi " + name )
# Out:
# kya chahiye aryan
# hi aryan

# %%
color = input("fav color")
name = input("kya naam hai")
print( name  + " likes " + color )
# Out:
# fav colorwhite
# kya naam haiaryan
# aryan likes white

# %%
weight = input("kya wg hai tera")
wg_kg = int( weight ) / 2.2
print(wg_kg)
# Out:
# kya wg hai tera45
# 20.454545454545453
